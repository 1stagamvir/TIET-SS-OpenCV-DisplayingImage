# %% [markdown]
# <a href="https://colab.research.google.com/github/1stagamvir/TIET-SS-OpenCV-DisplayingImage/blob/main/DisplayingImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Displaying Image

# %%
import cv2
import numpy as np

# %%
image = cv2.imread('/content/logo.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %% [markdown]
# Show the image with matplotlib

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Creating title

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
imshow("Car", image)
